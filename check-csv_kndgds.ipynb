# %%
import pandas as pd

# %%
df = pd.read_csv("kndrgdens_1.csv")
df.head(2)
# Out:
#                                             fullname  \
# 0   Государственное бюджетное образовательное учр...
# 1   Государственное бюджетное образовательное учр...
#
#                   shortname number                                category  \
# 0   ГБОУ детский сад № 1439  1 439   Дошкольное образовательное учреждение
# 1    ГБОУ детский сад № 938    938   Дошкольное образовательное учреждение
#
#                    vid_uchrezhdeniya organiz_pravov_forma  \
# 0   Детский сад компенсирующего вида            Бюджетное
# 1                        Детский сад            Бюджетное
#
#                                          podchinenie  \
# 0   Северо-Восточное окружное управление образования
# 1   Северо-Восточное окружное управление образования
#
#                                          address        telephone  \
# 0      "127273 г. Москва, ул. Отрадная, д. 5 "Б"  (499) 907-63-66
# 1   127349, город Москва, улица Лескова, дом 6 Г  (499) 909-00-44
#
#                       email                      location
# 0        detsad1439@mail.ru  POINT(37.6076187 55.8591187)
# 1   detskiysad938@yandex.ru  POINT(37.5925685 55.8970746)

# %%
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')
df['location'] = df.apply(
    lambda row: f"POINT({row['Longitude']} {row['Latitude']})"
    if pd.notna(row['Longitude']) and pd.notna(row['Latitude'])
    else None,
    axis=1
)
df.head()
# Out:
#                                             fullname  \
# 0   Государственное бюджетное образовательное учр...
# 1   Государственное бюджетное образовательное учр...
# 2   Государственное бюджетное образовательное учр...
# 3   Государственное бюджетное образовательное учр...
# 4   Государственное бюджетное образовательное учр...
#
#                   shortname number                                category  \
# 0   ГБОУ детский сад № 1264  1 264   Дошкольное образовательное учреждение
# 1   ГБОУ детский сад № 2642  2 642   Дошкольное образовательное учреждение
# 2   ГБОУ детский сад № 2198  2 198   Дошкольное образовательное учреждение
# 3    ГБОУ детский сад № 813    813   Дошкольное образовательное учреждение
# 4    ГБОУ детский сад № 283    283   Дошкольное образовательное учреждение
#
#                     vid_uchrezhdeniya organiz_pravov_forma  \
# 0                         Детский сад            Бюджетное
# 1                         Детский сад            Бюджетное
# 2   Детский сад комбинированного вида            Бюджетное
# 3   Детский сад комбинированного вида            Бюджетное
# 4   Детский сад комбинированного вида            Бюджетное
#
#                                       podchinenie  \
# 0   Юго-Восточное окружное управление образования
# 1        Северное окружное управление образования
# 2       Восточное окружное управление образования
# 3       Восточное окружное управление образования
# 4       Восточное окружное управление образования
#
#                                         address   Latitude  Longitude  \
# 0          115432, г.Москва, ул. Трофимова,д.11  55.703335  37.668909
# 1   125299, г. Москва, ул. Клары Цеткин, д. 15Б  55.820502  37.516988
# 2    107113, г. Москва, Поперечный просек д. 1А  55.794986  37.656089
# 3       111402, г. Москва, ул. Кетчерская, д.6А  55.742684  37.823713
# 4      105484,г. Москва, 13-я Парковая ул.,д.30  55.806057  37.814724
#
#          telephone                                              email  \
# 0  (495) 679-06-67   d_c1264@mail.ru; d_c1264_1@mail.ru; d-c1264@y...
# 1  (495) 601-46-94                                 detsad2642@mail.ru
# 2  (499) 269-89-82                               gou.ds2198@gmail.com
# 3  (495) 375-77-30                            detskij-sad-813@mail.ru
# 4  (495) 468-54-28                                    dc283@yandex.ru
#
#                        location
# 0  POINT(37.6689089 55.7033346)
# 1  POINT(37.5169885 55.8205021)
# 2  POINT(37.6560889 55.7949863)
# 3  POINT(37.8237126 55.7426839)
# 4    POINT(37.814724 55.806057)

# %%
# Удаление лишних столбцов
df = df.drop(columns=['Latitude', 'Longitude'])
df.head(3)
#df.tail(3)
# Out:
#                                             fullname  \
# 0   Государственное бюджетное образовательное учр...
# 1   Государственное бюджетное образовательное учр...
# 2   Государственное бюджетное образовательное учр...
#
#                   shortname number                                category  \
# 0   ГБОУ детский сад № 1264  1 264   Дошкольное образовательное учреждение
# 1   ГБОУ детский сад № 2642  2 642   Дошкольное образовательное учреждение
# 2   ГБОУ детский сад № 2198  2 198   Дошкольное образовательное учреждение
#
#                     vid_uchrezhdeniya organiz_pravov_forma  \
# 0                         Детский сад            Бюджетное
# 1                         Детский сад            Бюджетное
# 2   Детский сад комбинированного вида            Бюджетное
#
#                                       podchinenie  \
# 0   Юго-Восточное окружное управление образования
# 1        Северное окружное управление образования
# 2       Восточное окружное управление образования
#
#                                         address        telephone  \
# 0          115432, г.Москва, ул. Трофимова,д.11  (495) 679-06-67
# 1   125299, г. Москва, ул. Клары Цеткин, д. 15Б  (495) 601-46-94
# 2    107113, г. Москва, Поперечный просек д. 1А  (499) 269-89-82
#
#                                                email  \
# 0   d_c1264@mail.ru; d_c1264_1@mail.ru; d-c1264@y...
# 1                                 detsad2642@mail.ru
# 2                               gou.ds2198@gmail.com
#
#                        location
# 0  POINT(37.6689089 55.7033346)
# 1  POINT(37.5169885 55.8205021)
# 2  POINT(37.6560889 55.7949863)

# %%
df.info()
#df.describe()
#df.columns
#df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fullname              694 non-null    str
#  1   shortname             694 non-null    str
#  2   number                694 non-null    str
#  3   category              694 non-null    str
#  4   vid_uchrezhdeniya     694 non-null    str
#  5   organiz_pravov_forma  694 non-null    str
#  6   podchinenie           694 non-null    str
#  7   address               694 non-null    str
#  8   telephone             694 non-null    str
#  9   email                 694 non-null    str
#  10  location              694 non-null    str
# dtypes: str(11)
# memory usage: 59.8 KB

# %%
df.to_csv("kndrgdens_2.csv", index=False, encoding="utf-8")
