# %%
import pandas as pd

# %%
df = pd.read_csv("kndgds_f1.csv")
df.head(2)
# Out:
#                                             fullname  \
# 0   Государственное бюджетное образовательное учр...
# 1   Государственное бюджетное образовательное учр...
#
#                   shortname number                                category  \
# 0   ГБОУ детский сад № 1439  1 439   Дошкольное образовательное учреждение
# 1    ГБОУ детский сад № 938    938   Дошкольное образовательное учреждение
#
#                    vid_uchrezhdeniya organiz_pravov_forma  \
# 0   Детский сад компенсирующего вида            Бюджетное
# 1                        Детский сад            Бюджетное
#
#                                          podchinenie  \
# 0   Северо-Восточное окружное управление образования
# 1   Северо-Восточное окружное управление образования
#
#                                          address   Latitude  Longitude  \
# 0      "127273 г. Москва, ул. Отрадная, д. 5 "Б"  55.859119  37.607619
# 1   127349, город Москва, улица Лескова, дом 6 Г  55.897075  37.592568
#
#          telephone                     email
# 0  (499) 907-63-66        detsad1439@mail.ru
# 1  (499) 909-00-44   detskiysad938@yandex.ru

# %%
df['Latitude'] = pd.to_numeric(df['Latitude'], errors='coerce')
df['Longitude'] = pd.to_numeric(df['Longitude'], errors='coerce')
df['location'] = df.apply(
    lambda row: f"POINT({row['Longitude']} {row['Latitude']})"
    if pd.notna(row['Longitude']) and pd.notna(row['Latitude'])
    else None,
    axis=1
)
df.head()
# Out:
#                                             fullname  \
# 0   Государственное бюджетное образовательное учр...
# 1   Государственное бюджетное образовательное учр...
# 2   Государственное бюджетное образовательное учр...
# 3   Государственное бюджетное образовательное учр...
# 4   Государственное бюджетное образовательное учр...
#
#                   shortname number                                category  \
# 0   ГБОУ детский сад № 1439  1 439   Дошкольное образовательное учреждение
# 1    ГБОУ детский сад № 938    938   Дошкольное образовательное учреждение
# 2   ГБОУ детский сад № 1243  1 243   Дошкольное образовательное учреждение
# 3   ГБОУ детский сад № 1432  1 432   Дошкольное образовательное учреждение
# 4    ГБОУ детский сад № 824    824   Дошкольное образовательное учреждение
#
#                    vid_uchrezhdeniya organiz_pravov_forma  \
# 0   Детский сад компенсирующего вида            Бюджетное
# 1                        Детский сад            Бюджетное
# 2   Детский сад компенсирующего вида            Бюджетное
# 3                        Детский сад            Бюджетное
# 4                        Детский сад            Бюджетное
#
#                                          podchinenie  \
# 0   Северо-Восточное окружное управление образования
# 1   Северо-Восточное окружное управление образования
# 2       Юго-Западное окружное управление образования
# 3       Юго-Западное окружное управление образования
# 4           Западное окружное управление образования
#
#                                              address   Latitude  Longitude  \
# 0          "127273 г. Москва, ул. Отрадная, д. 5 "Б"  55.859119  37.607619
# 1       127349, город Москва, улица Лескова, дом 6 Г  55.897075  37.592568
# 2             119333, г. Москва, ул. Фотиевой, дом 8  55.701004  37.562349
# 3   119331, г.Москва, улица Марии Ульяновой, дом ...  55.680765  37.520382
# 4            121615, г.Москва, ул. Ельнинская, д. 16  55.738647  37.424016
#
#          telephone                                      email  \
# 0  (499) 907-63-66                         detsad1439@mail.ru
# 1  (499) 909-00-44                    detskiysad938@yandex.ru
# 2  8(499)137-35-75   dou1243@ou.mosuzedu.ru; tngulakova@bk.ru
# 3  8(499)138-38-47                     dou1432@ou.mosuzedu.ru
# 4  (499) 141-75-87                               dou824@bk.ru
#
#                               location
# 0         POINT(37.6076187 55.8591187)
# 1         POINT(37.5925685 55.8970746)
# 2  POINT(37.5623493 55.70100369999999)
# 3          POINT(37.5203819 55.680765)
# 4         POINT(37.4240156 55.7386473)

# %%
# Удаление лишних столбцов
df = df.drop(columns=['Latitude', 'Longitude'])
df.head(3)
#df.tail(3)
# Out:
#                                             fullname  \
# 0   Государственное бюджетное образовательное учр...
# 1   Государственное бюджетное образовательное учр...
# 2   Государственное бюджетное образовательное учр...
#
#                   shortname number                                category  \
# 0   ГБОУ детский сад № 1439  1 439   Дошкольное образовательное учреждение
# 1    ГБОУ детский сад № 938    938   Дошкольное образовательное учреждение
# 2   ГБОУ детский сад № 1243  1 243   Дошкольное образовательное учреждение
#
#                    vid_uchrezhdeniya organiz_pravov_forma  \
# 0   Детский сад компенсирующего вида            Бюджетное
# 1                        Детский сад            Бюджетное
# 2   Детский сад компенсирующего вида            Бюджетное
#
#                                          podchinenie  \
# 0   Северо-Восточное окружное управление образования
# 1   Северо-Восточное окружное управление образования
# 2       Юго-Западное окружное управление образования
#
#                                          address        telephone  \
# 0      "127273 г. Москва, ул. Отрадная, д. 5 "Б"  (499) 907-63-66
# 1   127349, город Москва, улица Лескова, дом 6 Г  (499) 909-00-44
# 2         119333, г. Москва, ул. Фотиевой, дом 8  8(499)137-35-75
#
#                                        email  \
# 0                         detsad1439@mail.ru
# 1                    detskiysad938@yandex.ru
# 2   dou1243@ou.mosuzedu.ru; tngulakova@bk.ru
#
#                               location
# 0         POINT(37.6076187 55.8591187)
# 1         POINT(37.5925685 55.8970746)
# 2  POINT(37.5623493 55.70100369999999)

# %%
df.info()
#df.describe()
#df.columns
#df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fullname              1000 non-null   str
#  1   shortname             1000 non-null   str
#  2   number                1000 non-null   str
#  3   category              1000 non-null   str
#  4   vid_uchrezhdeniya     1000 non-null   str
#  5   organiz_pravov_forma  1000 non-null   str
#  6   podchinenie           1000 non-null   str
#  7   address               1000 non-null   str
#  8   telephone             1000 non-null   str
#  9   email                 1000 non-null   str
#  10  location              1000 non-null   str
# dtypes: str(11)
# memory usage: 86.1 KB

# %%
df.to_csv("kndrgdens_1.csv", index=False, encoding="utf-8")
