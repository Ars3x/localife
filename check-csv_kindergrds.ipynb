# %%
import pandas as pd

# %%
df = pd.read_csv("kindergardens.csv", sep=";")
df.head(2)
# Out:
#     global_id                                          poln_name  \
# 0   global_id                                Полное наименование
# 1  2631639327   Государственное бюджетное образовательное учр...
#
#                  kratk_name  nomer                         tipe_uchrezhden  \
# 0      Краткое наименование  Номер                          Тип учреждения
# 1   ГБОУ детский сад № 1439   1439   Дошкольное образовательное учреждение
#
#                    vid_uchrezhdeniya           organiz_pravov_forma  \
# 0                     Вид учреждения  Организационно-правовая форма
# 1   Детский сад компенсирующего вида                      Бюджетное
#
#                                          podchinenie  \
# 0                                         Подчинение
# 1   Северо-Восточное окружное управление образования
#
#                               yuridich_adress        telephone  \
# 0                           Юридический адрес          Телефон
# 1   "127273 г. Москва, ул. Отрадная, д. 5 "Б"  (499) 907-63-66
#
#                      email  Unnamed: 11
# 0  Адрес электронной почты          NaN
# 1       detsad1439@mail.ru          NaN

# %%
# Удаление одного столбца
df = df.drop(columns=['Unnamed: 11'])

# Удаление нескольких столбцов сразу
# df = df.drop(columns=['столбец_1', 'столбец_2'])
df.head(3)
#df.tail(3)
# Out:
#                                            poln_name  \
# 0                                Полное наименование
# 1   Государственное бюджетное образовательное учр...
# 2   Государственное бюджетное образовательное учр...
#
#                  kratk_name  nomer                         tipe_uchrezhden  \
# 0      Краткое наименование  Номер                          Тип учреждения
# 1   ГБОУ детский сад № 1439   1439   Дошкольное образовательное учреждение
# 2    ГБОУ детский сад № 938    938   Дошкольное образовательное учреждение
#
#                    vid_uchrezhdeniya           organiz_pravov_forma  \
# 0                     Вид учреждения  Организационно-правовая форма
# 1   Детский сад компенсирующего вида                      Бюджетное
# 2                        Детский сад                      Бюджетное
#
#                                          podchinenie  \
# 0                                         Подчинение
# 1   Северо-Восточное окружное управление образования
# 2   Северо-Восточное окружное управление образования
#
#                                  yuridich_adress        telephone  \
# 0                              Юридический адрес          Телефон
# 1      "127273 г. Москва, ул. Отрадная, д. 5 "Б"  (499) 907-63-66
# 2   127349, город Москва, улица Лескова, дом 6 Г  (499) 909-00-44
#
#                       email
# 0   Адрес электронной почты
# 1        detsad1439@mail.ru
# 2   detskiysad938@yandex.ru

# %%
df.info()
#df.describe()
#df.columns
#df.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3493 entries, 0 to 3492
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   poln_name             3493 non-null   str
#  1   kratk_name            3493 non-null   str
#  2   nomer                 3493 non-null   str
#  3   tipe_uchrezhden       3493 non-null   str
#  4   vid_uchrezhdeniya     3493 non-null   str
#  5   organiz_pravov_forma  3493 non-null   str
#  6   podchinenie           3493 non-null   str
#  7   yuridich_adress       3493 non-null   str
#  8   telephone             3493 non-null   str
#  9   email                 3493 non-null   str
# dtypes: str(10)
# memory usage: 273.0 KB

# %%
df['kratk_name'].nunique()
# Out:
# 3454

# %%
df['nomer'].nunique()
# Out:
# 2218

# %%
df['nomer'].unique()
# Out:
# <StringArray>
# ['Номер', ' 1439',  ' 938', ' 1243',  ' 978', ' 1432',  ' 824', ' 2703',
#     ' —', ' 2435',
#  ...
#  ' 1072', ' 2740', ' 1404', ' 1309', ' 1728', ' 1996',  ' 378', ' 2556',
#   ' 154', ' 1397']
# Length: 2218, dtype: str

# %%
df = df.drop(index=0).reset_index(drop=True)

# %%
df.head(10)
# Out:
#               Category                                           FullName  \
# 0  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 1  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 2  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 3  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 4  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 5  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 6  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 7  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 8  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 9  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
#
#                        ShortName  \
# 0              ГБУЗ ДГП № 48 ДЗМ
# 1  ГБУЗ ДГП № 110 филиал № 3 ДЗМ
# 2  ГБУЗ ДГП № 131 филиал № 2 ДЗМ
# 3   ГБУЗ ДГП № 91 филиал № 2 ДЗМ
# 4  ГБУЗ ДГП № 150 филиал № 3 ДЗМ
# 5   ГБУЗ ДГП № 61 филиал № 2 ДЗМ
# 6  ГБУЗ ДГП № 122 филиал № 2 ДЗМ
# 7  ГБУЗ ДГП № 125 филиал № 2 ДЗМ
# 8  ГБУЗ ДГП № 150 филиал № 2 ДЗМ
# 9   ГБУЗ ДГП № 48 филиал № 2 ДЗМ
#
#                                        ObjectAddress  \
# 0  AdmArea:Юго-Восточный административный округ\n...
# 1  AdmArea:Северо-Восточный административный окру...
# 2  AdmArea:Западный административный округ\nDistr...
# 3  AdmArea:Южный административный округ\nDistrict...
# 4  AdmArea:Юго-Восточный административный округ\n...
# 5  AdmArea:Юго-Восточный административный округ\n...
# 6  AdmArea:Восточный административный округ\nDist...
# 7  AdmArea:Северо-Восточный административный окру...
# 8  AdmArea:Юго-Восточный административный округ\n...
# 9  AdmArea:Юго-Восточный административный округ\n...
#
#                                              geoData  \
# 0  {coordinates=[[37.74188144, 55.694081483]], ty...
# 1  {coordinates=[[37.579720035, 55.814071213]], t...
# 2  {coordinates=[[37.514133891, 55.712573334]], t...
# 3  {coordinates=[[37.617093435, 55.714439742]], t...
# 4  {coordinates=[[37.74702014, 55.651710188]], ty...
# 5  {coordinates=[[37.66475943, 55.729622049]], ty...
# 6  {coordinates=[[37.802977987, 55.816576302]], t...
# 7  {coordinates=[[37.577723351, 55.901862208]], t...
# 8  {coordinates=[[37.769740489, 55.670141578]], t...
# 9  {coordinates=[[37.776995007, 55.701673799]], t...
#
#                                              address
# 0  Российская Федерация, город Москва, внутригоро...
# 1  Российская Федерация, город Москва, внутригоро...
# 2  Российская Федерация, город Москва, внутригоро...
# 3  Российская Федерация, город Москва, внутригоро...
# 4  Российская Федерация, город Москва, внутригоро...
# 5  Российская Федерация, город Москва, внутригоро...
# 6  Российская Федерация, город Москва, внутригоро...
# 7  Российская Федерация, город Москва, внутригоро...
# 8  Российская Федерация, город Москва, внутригоро...
# 9  Российская Федерация, город Москва, внутригоро...

# %%
import re

def to_point_wkt(value):
    lon, lat = re.findall(r"[-\d.]+", value)[:2]
    return f"POINT({lon} {lat})"

df["location"] = df["geoData"].apply(to_point_wkt)

# %%
df.head(10)
# Out:
#               Category                                           FullName  \
# 0  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 1  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 2  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 3  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 4  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 5  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 6  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 7  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 8  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 9  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
#
#                        ShortName  \
# 0              ГБУЗ ДГП № 48 ДЗМ
# 1  ГБУЗ ДГП № 110 филиал № 3 ДЗМ
# 2  ГБУЗ ДГП № 131 филиал № 2 ДЗМ
# 3   ГБУЗ ДГП № 91 филиал № 2 ДЗМ
# 4  ГБУЗ ДГП № 150 филиал № 3 ДЗМ
# 5   ГБУЗ ДГП № 61 филиал № 2 ДЗМ
# 6  ГБУЗ ДГП № 122 филиал № 2 ДЗМ
# 7  ГБУЗ ДГП № 125 филиал № 2 ДЗМ
# 8  ГБУЗ ДГП № 150 филиал № 2 ДЗМ
# 9   ГБУЗ ДГП № 48 филиал № 2 ДЗМ
#
#                                        ObjectAddress  \
# 0  AdmArea:Юго-Восточный административный округ\n...
# 1  AdmArea:Северо-Восточный административный окру...
# 2  AdmArea:Западный административный округ\nDistr...
# 3  AdmArea:Южный административный округ\nDistrict...
# 4  AdmArea:Юго-Восточный административный округ\n...
# 5  AdmArea:Юго-Восточный административный округ\n...
# 6  AdmArea:Восточный административный округ\nDist...
# 7  AdmArea:Северо-Восточный административный окру...
# 8  AdmArea:Юго-Восточный административный округ\n...
# 9  AdmArea:Юго-Восточный административный округ\n...
#
#                                              geoData  \
# 0  {coordinates=[[37.74188144, 55.694081483]], ty...
# 1  {coordinates=[[37.579720035, 55.814071213]], t...
# 2  {coordinates=[[37.514133891, 55.712573334]], t...
# 3  {coordinates=[[37.617093435, 55.714439742]], t...
# 4  {coordinates=[[37.74702014, 55.651710188]], ty...
# 5  {coordinates=[[37.66475943, 55.729622049]], ty...
# 6  {coordinates=[[37.802977987, 55.816576302]], t...
# 7  {coordinates=[[37.577723351, 55.901862208]], t...
# 8  {coordinates=[[37.769740489, 55.670141578]], t...
# 9  {coordinates=[[37.776995007, 55.701673799]], t...
#
#                                              address  \
# 0  Российская Федерация, город Москва, внутригоро...
# 1  Российская Федерация, город Москва, внутригоро...
# 2  Российская Федерация, город Москва, внутригоро...
# 3  Российская Федерация, город Москва, внутригоро...
# 4  Российская Федерация, город Москва, внутригоро...
# 5  Российская Федерация, город Москва, внутригоро...
# 6  Российская Федерация, город Москва, внутригоро...
# 7  Российская Федерация, город Москва, внутригоро...
# 8  Российская Федерация, город Москва, внутригоро...
# 9  Российская Федерация, город Москва, внутригоро...
#
#                            geometry                          location
# 0   POINT(37.74188144 55.694081483)   POINT(37.74188144 55.694081483)
# 1  POINT(37.579720035 55.814071213)  POINT(37.579720035 55.814071213)
# 2  POINT(37.514133891 55.712573334)  POINT(37.514133891 55.712573334)
# 3  POINT(37.617093435 55.714439742)  POINT(37.617093435 55.714439742)
# 4   POINT(37.74702014 55.651710188)   POINT(37.74702014 55.651710188)
# 5   POINT(37.66475943 55.729622049)   POINT(37.66475943 55.729622049)
# 6  POINT(37.802977987 55.816576302)  POINT(37.802977987 55.816576302)
# 7  POINT(37.577723351 55.901862208)  POINT(37.577723351 55.901862208)
# 8  POINT(37.769740489 55.670141578)  POINT(37.769740489 55.670141578)
# 9  POINT(37.776995007 55.701673799)  POINT(37.776995007 55.701673799)

# %%
df.drop(columns=["ObjectAddress"], inplace=True)
df.drop(columns=["geoData"], inplace=True)
df.drop(columns=["geometry"], inplace=True)
df.head(10)
# Out:
#               Category                                           FullName  \
# 0  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 1  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 2  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 3  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 4  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 5  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 6  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 7  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 8  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
# 9  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
#
#                        ShortName  \
# 0              ГБУЗ ДГП № 48 ДЗМ
# 1  ГБУЗ ДГП № 110 филиал № 3 ДЗМ
# 2  ГБУЗ ДГП № 131 филиал № 2 ДЗМ
# 3   ГБУЗ ДГП № 91 филиал № 2 ДЗМ
# 4  ГБУЗ ДГП № 150 филиал № 3 ДЗМ
# 5   ГБУЗ ДГП № 61 филиал № 2 ДЗМ
# 6  ГБУЗ ДГП № 122 филиал № 2 ДЗМ
# 7  ГБУЗ ДГП № 125 филиал № 2 ДЗМ
# 8  ГБУЗ ДГП № 150 филиал № 2 ДЗМ
# 9   ГБУЗ ДГП № 48 филиал № 2 ДЗМ
#
#                                              address  \
# 0  Российская Федерация, город Москва, внутригоро...
# 1  Российская Федерация, город Москва, внутригоро...
# 2  Российская Федерация, город Москва, внутригоро...
# 3  Российская Федерация, город Москва, внутригоро...
# 4  Российская Федерация, город Москва, внутригоро...
# 5  Российская Федерация, город Москва, внутригоро...
# 6  Российская Федерация, город Москва, внутригоро...
# 7  Российская Федерация, город Москва, внутригоро...
# 8  Российская Федерация, город Москва, внутригоро...
# 9  Российская Федерация, город Москва, внутригоро...
#
#                            location
# 0   POINT(37.74188144 55.694081483)
# 1  POINT(37.579720035 55.814071213)
# 2  POINT(37.514133891 55.712573334)
# 3  POINT(37.617093435 55.714439742)
# 4   POINT(37.74702014 55.651710188)
# 5   POINT(37.66475943 55.729622049)
# 6  POINT(37.802977987 55.816576302)
# 7  POINT(37.577723351 55.901862208)
# 8  POINT(37.769740489 55.670141578)
# 9  POINT(37.776995007 55.701673799)

# %%
df_unique = df.drop_duplicates(subset=["ShortName"], keep="first")

# %%
# df_unique.info()
# df_unique.describe()
df['ShortName'].value_counts()
# df_unique['address'].value_counts().head(10)
# Out:
# ShortName
# ГБУЗ ДГП № 48 ДЗМ                        1
# ГБУЗ ДГП № 110 филиал № 3 ДЗМ            1
# ГБУЗ ДГП № 131 филиал № 2 ДЗМ            1
# ГБУЗ ДГП № 91 филиал № 2 ДЗМ             1
# ГБУЗ ДГП № 150 филиал № 3 ДЗМ            1
#                                         ..
# ГБУЗ ДГП № 130 ДЗМ                       1
# ГБУЗ ДГП № 145 ДЗМ. Детское отделение    1
# ГБУЗ ДГП № 105 ДЗМ                       1
# ГБУЗ ДГП № 69 филиал № 2 ДЗМ             1
# ГБУЗ ДГП № 118 филиал № 7 ДЗМ            1
# Name: count, Length: 201, dtype: int64

# %%
df_unique = df[df["ShortName"].str.len() > 0]

# %%
df_unique = df_unique[df_unique["ShortName"].notna()]
df_unique.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Category   201 non-null    str
#  1   FullName   201 non-null    str
#  2   ShortName  201 non-null    str
#  3   address    201 non-null    str
#  4   location   201 non-null    str
# dtypes: str(5)
# memory usage: 8.0 KB

# %%
df_unique = df_unique[~df_unique["ShortName"].str.contains("none", case=False, na=False)]
df_unique.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Category   201 non-null    str
#  1   FullName   201 non-null    str
#  2   ShortName  201 non-null    str
#  3   address    201 non-null    str
#  4   location   201 non-null    str
# dtypes: str(5)
# memory usage: 8.0 KB

# %%
df_unique['address'].value_counts()
# Out:
# address
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Рязанский, Волжский бульвар, дом 9                          2
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Текстильщики, улица Артюхиной, дом 27, корпус 3             1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Бутырский, улица Яблочкова, дом 3А, строение 1              1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Раменки, Мосфильмовская улица, дом 27А                      1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Даниловский, улица Лестева, дом 5                           1
#                                                                                                                                               ..
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Крылатское, улица Крылатские Холмы, дом 5                   1
# город Москва, Каширское шоссе, дом 57, корпус 1                                                                                                1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Старое Крюково, город Зеленоград, корпус 805, строение 1    1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Зюзино, Азовская улица, дом 20, корпус 2                    1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Южное Бутово, 2-я Мелитопольская улица, дом 13              1
# Name: count, Length: 200, dtype: int64

# %%
last = df["address"].str.split(",").str[-1].str.strip()
has_number = last.str.contains(r"\d", na=False, regex=True)

df_unique = df_unique[has_number]  # оставить только строки, где в «хвосте» адреса есть цифра
df_unique.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Category   201 non-null    str
#  1   FullName   201 non-null    str
#  2   ShortName  201 non-null    str
#  3   address    201 non-null    str
#  4   location   201 non-null    str
# dtypes: str(5)
# memory usage: 8.0 KB

# %%
df_unique['address'].value_counts()
# Out:
# address
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Рязанский, Волжский бульвар, дом 9                          2
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Текстильщики, улица Артюхиной, дом 27, корпус 3             1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Бутырский, улица Яблочкова, дом 3А, строение 1              1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Раменки, Мосфильмовская улица, дом 27А                      1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Даниловский, улица Лестева, дом 5                           1
#                                                                                                                                               ..
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Крылатское, улица Крылатские Холмы, дом 5                   1
# город Москва, Каширское шоссе, дом 57, корпус 1                                                                                                1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Старое Крюково, город Зеленоград, корпус 805, строение 1    1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Зюзино, Азовская улица, дом 20, корпус 2                    1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Южное Бутово, 2-я Мелитопольская улица, дом 13              1
# Name: count, Length: 200, dtype: int64

# %%
df_unique["address"] = df_unique["address"].str.replace(
    r"(\d+)\s*([кКkK])\s*(\d+)",
    r"\1 корпус \3",
    regex=True,
)

# %%
df_unique['address'].value_counts()
# Out:
# address
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Краснопахорский, посёлок Шишкин Лес, дом 32, строение 1                  2
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Коммунарка, посёлок Коммунарка, Фитарёвская улица, дом 27, строение 1    2
# город Москва, Пехотная улица, дом 3, строение 16                                                                                                            2
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Богородское, Игральная улица, дом 8                                      2
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Москворечье-Сабурово, улица Кошкина, дом 21                              2
#                                                                                                                                                            ..
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Западное Дегунино, Ангарская улица, дом 24                               1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Западное Дегунино, улица Маршала Федоренко, дом 6, строение 1            1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Ховрино, Петрозаводская улица, дом 26                                    1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Куркино, Родионовская улица, дом 10, корпус 2                            1
# Российская Федерация, город Москва, внутригородская территория муниципальный округ Левобережный, Смольная улица, дом 53                                     1
# Name: count, Length: 257, dtype: int64

# %%
df_unique.head(1)
# Out:
#               Category                                           FullName  \
# 0  Поликлиника детская  Государственное бюджетное учреждение здравоохр...
#
#            ShortName                                            address  \
# 0  ГБУЗ ДГП № 48 ДЗМ  Российская Федерация, город Москва, внутригоро...
#
#                           location
# 0  POINT(37.74188144 55.694081483)

# %%
df_unique = df_unique.rename(columns={
    "Category": "category",
    "FullName": "fullname",
    "ShortName": "shortname",
    "Address": "address",
})

# %%
df_unique.to_csv("policlinics_2.csv", index=False, encoding="utf-8")
